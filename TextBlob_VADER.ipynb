# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import os 
os.chdir("/content/drive/My Drive/Sentiment Analysis Code")

# %%
# !pip install vadersentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 3.4MB/s
# ...

# %%
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
pos_count = 0
pos_correct = 0

neg_count = 0
neg_correct = 0


with open("positive.txt",'r') as file_1:
  for line in file_1.read().split('\n'):
    analysis = TextBlob(line)
    if analysis.sentiment.polarity > 0.1:
      pos_correct += 1
    pos_count += 1
    
with open("negative.txt",'r') as file_2:
  for line in file_2.read().split('\n'):
    analysis = TextBlob(line)
    if analysis.sentiment.polarity <= 0.1:
      neg_correct += 1
    neg_count += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-549bba1cd30e> in <module>()
#       6
#       7
# ----> 8 with open("positive.txt",'r') as file_1:
#       9   for line in file_1.read().split('\n'):
#      10     analysis = TextBlob(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'positive.txt'

# %%
print("Positive accuracy = {}% via samples {}".format(pos_correct/pos_count*100.0,pos_count))
print("Negative accuracy = {}% via samples {}".format(neg_correct/neg_count*100.0,neg_count))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-06f6d9456467> in <module>()
# ----> 1 print("Positive accuracy = {}% via samples {}".format(pos_correct/pos_count*100.0,pos_count))
#       2 print("Negative accuracy = {}% via samples {}".format(neg_correct/neg_count*100.0,neg_count))
#
# ZeroDivisionError: division by zero

# %%
pos_count = 0
pos_correct = 0

neg_count = 0
neg_correct = 0

with open("positive.txt",'r') as file_1:
  for line in file_1.read().split('\n'):
    analysis = TextBlob(line)
    if analysis.sentiment.subjectivity > 0.8:
      if analysis.sentiment.polarity > 0.1:
        pos_correct += 1
      pos_count += 1
    
with open("negative.txt",'r') as file_2:
  for line in file_2.read().split('\n'):
    analysis = TextBlob(line)
    if analysis.sentiment.subjectivity > 0.8:
      if analysis.sentiment.polarity <= 0.1:
        neg_correct += 1
      neg_count += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-e5c7f9dcc061> in <module>()
#       6 neg_correct = 0
#       7
# ----> 8 with open("positive.txt",'r') as file_1:
#       9   for line in file_1.read().split('\n'):
#      10     analysis = TextBlob(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'positive.txt'

# %%
print("Positive accuracy = {}% via samples {}".format(pos_correct/pos_count*100.0,pos_count))
print("Negative accuracy = {}% via samples {}".format(neg_correct/neg_count*100.0,neg_count))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-06f6d9456467> in <module>()
# ----> 1 print("Positive accuracy = {}% via samples {}".format(pos_correct/pos_count*100.0,pos_count))
#       2 print("Negative accuracy = {}% via samples {}".format(neg_correct/neg_count*100.0,neg_count))
#
# ZeroDivisionError: division by zero

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
pos_count = 0
pos_correct = 0

neg_count = 0
neg_correct = 0


with open("positive.txt",'r') as file_1:
  for line in file_1.read().split('\n'):
    vs = analyzer.polarity_scores(line)
    if vs['compound'] >= 0.5:
      pos_correct += 1
    pos_count += 1
    
with open("negative.txt",'r') as file_2:
  for line in file_2.read().split('\n'):
    analysis = TextBlob(line)
    if vs['compound'] <= -0.5:
      neg_correct += 1
    neg_count += 1

# %%
print("Positive accuracy = {}% via samples {}".format(pos_correct/pos_count*100.0,pos_count))
print("Negative accuracy = {}% via samples {}".format(neg_correct/neg_count*100.0,neg_count))
# Out:
# Positive accuracy = 42.62940735183796% via samples 5332
# Negative accuracy = 0.0% via samples 5332

# %%
vs = analyzer.polarity_scores("Product is very good.")
print(vs)
# Out:
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4927}
